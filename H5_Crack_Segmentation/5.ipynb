# %% [markdown]
# ## **Crack Segmentation**

# %% [markdown]
# Crack segmentation is an important task in structure investigation problems. For example, in the bridge investigation project, a done is controlled to fly around bridges to take pictures of different bridge surfaces. The pictures will be then processed by computer to detect potential regions on the bridge surface that might be damaged. The more accurate the model is, the less human effort we need to process these images. Otherwise, the operators will have to check every single image, which is boring and error-prone.

# %% [markdown]
# Download the dataset form google drive. And use the link to colab.

# %% [markdown]
# ![1664357468670.png](data:image/png;base64,...)

# %%
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=148nCkszdcztSjhSrLUkyV8xqnfdvRdWC' -O 111.zip
# !unzip 111.zip
# Out:
# --2022-09-28 09:27:37--  https://docs.google.com/uc?export=download&id=148nCkszdcztSjhSrLUkyV8xqnfdvRdWC
# Resolving docs.google.com (docs.google.com)... 173.194.216.101, 173.194.216.100, 173.194.216.113, ...
# Connecting to docs.google.com (docs.google.com)|173.194.216.101|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-08-0s-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/l19fee7h8i38m6e13haivbt5ipqi3dlq/1664357250000/13842625950226300854/*/148nCkszdcztSjhSrLUkyV8xqnfdvRdWC?e=download&uuid=e6ac3712-fc13-4527-8fba-a0c6ae4ad832 [following]
# Warning: wildcards not supported in HTTP.
# --2022-09-28 09:27:40--  https://doc-08-0s-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/l19fee7h8i38m6e13haivbt5ipqi3dlq/1664357250000/13842625950226300854/*/148nCkszdcztSjhSrLUkyV8xqnfdvRdWC?e=download&uuid=e6ac3712-fc13-4527-8fba-a0c6ae4ad832
# Resolving doc-08-0s-docs.googleusercontent.com (doc-08-0s-docs.googleusercontent.com)... 108.177.13.132, 2607:f8b0:400c:c09::84
# Connecting to doc-08-0s-docs.googleusercontent.com (doc-08-0s-docs.googleusercontent.com)|108.177.13.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2449169 (2.3M) [application/x-zip-compressed]
# Saving to: ‘111.zip’
#
# 111.zip             100%[===================>]   2.33M  --.-KB/s    in 0.02s
#
# 2022-09-28 09:27:40 (133 MB/s) - ‘111.zip’ saved [2449169/2449169]
#
# Archive:  111.zip
#    creating: Negative/
#   inflating: Negative/00001.jpg
#   inflating: Negative/00002.jpg
#   inflating: Negative/00003.jpg
#   inflating: Negative/00004.jpg
#   inflating: Negative/00005.jpg
#   inflating: Negative/00006.jpg
#   inflating: Negative/00007.jpg
#   inflating: Negative/00008.jpg
#   inflating: Negative/00009.jpg
#   inflating: Negative/00010.jpg
#   inflating: Negative/00011.jpg
#   inflating: Negative/00012.jpg
#   inflating: Negative/00013.jpg
#   inflating: Negative/00014.jpg
#   inflating: Negative/00015.jpg
#   inflating: Negative/00016.jpg
#   inflating: Negative/00017.jpg
#   inflating: Negative/00018.jpg
#   inflating: Negative/00019.jpg
#   inflating: Negative/00020.jpg
#   inflating: Negative/00021.jpg
#   inflating: Negative/00022.jpg
#   inflating: Negative/00023.jpg
#   inflating: Negative/00024.jpg
#   inflating: Negative/00025.jpg
#   inflating: Negative/00026.jpg
#   inflating: Negative/00027.jpg
#   inflating: Negative/00028.jpg
#   inflating: Negative/00029.jpg
#   inflating: Negative/00030.jpg
#   inflating: Negative/00031.jpg
#   inflating: Negative/00032.jpg
#   inflating: Negative/00033.jpg
#   inflating: Negative/00034.jpg
#   inflating: Negative/00035.jpg
#   inflating: Negative/00036.jpg
#   inflating: Negative/00037.jpg
#   inflating: Negative/00038.jpg
#   inflating: Negative/00039.jpg
#   inflating: Negative/00040.jpg
#   inflating: Negative/00041.jpg
#   inflating: Negative/00042.jpg
#   inflating: Negative/00043.jpg
#   inflating: Negative/00044.jpg
#   inflating: Negative/00045.jpg
#   inflating: Negative/00046.jpg
#   inflating: Negative/00047.jpg
#   inflating: Negative/00048.jpg
#   inflating: Negative/00049.jpg
#   inflating: Negative/00050.jpg
#   inflating: Negative/00051.jpg
#   inflating: Negative/00052.jpg
#   inflating: Negative/00053.jpg
#   inflating: Negative/00054.jpg
#   inflating: Negative/00055.jpg
#   inflating: Negative/00056.jpg
#   inflating: Negative/00057.jpg
#   inflating: Negative/00058.jpg
#   inflating: Negative/00059.jpg
#   inflating: Negative/00060.jpg
#   inflating: Negative/00061.jpg
#   inflating: Negative/00062.jpg
#   inflating: Negative/00063.jpg
#   inflating: Negative/00064.jpg
#   inflating: Negative/00065.jpg
#   inflating: Negative/00066.jpg
#   inflating: Negative/00067.jpg
#   inflating: Negative/00068.jpg
#   inflating: Negative/00069.jpg
#   inflating: Negative/00070.jpg
#   inflating: Negative/00071.jpg
#   inflating: Negative/00072.jpg
#   inflating: Negative/00073.jpg
#   inflating: Negative/00074.jpg
#   inflating: Negative/00075.jpg
#   inflating: Negative/00076.jpg
#   inflating: Negative/00077.jpg
#   inflating: Negative/00078.jpg
#   inflating: Negative/00079.jpg
#   inflating: Negative/00080.jpg
#   inflating: Negative/00081.jpg
#   inflating: Negative/00082.jpg
#   inflating: Negative/00083.jpg
#   inflating: Negative/00084.jpg
#   inflating: Negative/00085.jpg
#   inflating: Negative/00086.jpg
#   inflating: Negative/00087.jpg
#   inflating: Negative/00088.jpg
#   inflating: Negative/00089.jpg
#   inflating: Negative/00090.jpg
#   inflating: Negative/00091.jpg
#   inflating: Negative/00092.jpg
#   inflating: Negative/00093.jpg
#   inflating: Negative/00094.jpg
#   inflating: Negative/00095.jpg
#   inflating: Negative/00096.jpg
#   inflating: Negative/00097.jpg
#   inflating: Negative/00098.jpg
#   inflating: Negative/00099.jpg
#   inflating: Negative/00100.jpg
#   inflating: Negative/00101.jpg
#   inflating: Negative/00102.jpg
#   inflating: Negative/00103.jpg
#   inflating: Negative/00104.jpg
#   inflating: Negative/00105.jpg
#   inflating: Negative/00106.jpg
#   inflating: Negative/00107.jpg
#   inflating: Negative/00108.jpg
#   inflating: Negative/00109.jpg
#   inflating: Negative/00110.jpg
#   inflating: Negative/00111.jpg
#   inflating: Negative/00112.jpg
#   inflating: Negative/00113.jpg
#   inflating: Negative/00114.jpg
#   inflating: Negative/00115.jpg
#   inflating: Negative/00116.jpg
#   inflating: Negative/00117.jpg
#   inflating: Negative/00118.jpg
#   inflating: Negative/00119.jpg
#   inflating: Negative/00120.jpg
#   inflating: Negative/00121.jpg
#   inflating: Negative/00122.jpg
#   inflating: Negative/00123.jpg
#   inflating: Negative/00124.jpg
#   inflating: Negative/00125.jpg
#   inflating: Negative/00126.jpg
#   inflating: Negative/00127.jpg
#   inflating: Negative/00128.jpg
#   inflating: Negative/00129.jpg
#   inflating: Negative/00130.jpg
#   inflating: Negative/00131.jpg
#   inflating: Negative/00132.jpg
#   inflating: Negative/00133.jpg
#   inflating: Negative/00134.jpg
#   inflating: Negative/00135.jpg
#   inflating: Negative/00136.jpg
#   inflating: Negative/00137.jpg
#   inflating: Negative/00138.jpg
#   inflating: Negative/00139.jpg
#   inflating: Negative/00140.jpg
#   inflating: Negative/00141.jpg
#   inflating: Negative/00142.jpg
#   inflating: Negative/00143.jpg
#   inflating: Negative/00144.jpg
#   inflating: Negative/00145.jpg
#   inflating: Negative/00146.jpg
#   inflating: Negative/00147.jpg
#   inflating: Negative/00148.jpg
#   inflating: Negative/00149.jpg
#   inflating: Negative/00150.jpg
#   inflating: Negative/00151.jpg
#   inflating: Negative/00152.jpg
#   inflating: Negative/00153.jpg
#   inflating: Negative/00154.jpg
#   inflating: Negative/00155.jpg
#   inflating: Negative/00156.jpg
#   inflating: Negative/00157.jpg
#   inflating: Negative/00158.jpg
#   inflating: Negative/00159.jpg
#   inflating: Negative/00160.jpg
#   inflating: Negative/00161.jpg
#   inflating: Negative/00162.jpg
#   inflating: Negative/00163.jpg
#   inflating: Negative/00164.jpg
#   inflating: Negative/00165.jpg
#   inflating: Negative/00166.jpg
#   inflating: Negative/00167.jpg
#   inflating: Negative/00168.jpg
#   inflating: Negative/00169.jpg
#   inflating: Negative/00170.jpg
#   inflating: Negative/00171.jpg
#   inflating: Negative/00172.jpg
#   inflating: Negative/00173.jpg
#   inflating: Negative/00174.jpg
#   inflating: Negative/00175.jpg
#   inflating: Negative/00176.jpg
#   inflating: Negative/00177.jpg
#   inflating: Negative/00178.jpg
#   inflating: Negative/00179.jpg
#   inflating: Negative/00180.jpg
#   inflating: Negative/00181.jpg
#   inflating: Negative/00182.jpg
#   inflating: Negative/00183.jpg
#   inflating: Negative/00184.jpg
#   inflating: Negative/00185.jpg
#   inflating: Negative/00186.jpg
#   inflating: Negative/00187.jpg
#   inflating: Negative/00188.jpg
#   inflating: Negative/00189.jpg
#   inflating: Negative/00190.jpg
#   inflating: Negative/00191.jpg
#   inflating: Negative/00192.jpg
#   inflating: Negative/00193.jpg
#   inflating: Negative/00194.jpg
#   inflating: Negative/00195.jpg
#   inflating: Negative/00196.jpg
#   inflating: Negative/00197.jpg
#   inflating: Negative/00198.jpg
#   inflating: Negative/00199.jpg
#   inflating: Negative/00200.jpg
#   inflating: Negative/00201.jpg
#   inflating: Negative/00202.jpg
#   inflating: Negative/00203.jpg
#   inflating: Negative/00204.jpg
#   inflating: Negative/00205.jpg
#   inflating: Negative/00206.jpg
#   inflating: Negative/00207.jpg
#    creating: Positive/
#   inflating: Positive/00001.jpg
#   inflating: Positive/00002.jpg
#   inflating: Positive/00003.jpg
#   inflating: Positive/00004.jpg
#   inflating: Positive/00005.jpg
#   inflating: Positive/00006.jpg
#   inflating: Positive/00007.jpg
#   inflating: Positive/00008.jpg
#   inflating: Positive/00009.jpg
#   inflating: Positive/00010.jpg
#   inflating: Positive/00011.jpg
#   inflating: Positive/00012.jpg
#   inflating: Positive/00013.jpg
#   inflating: Positive/00014.jpg
#   inflating: Positive/00015.jpg
#   inflating: Positive/00016.jpg
#   inflating: Positive/00017.jpg
#   inflating: Positive/00018.jpg
#   inflating: Positive/00019.jpg
#   inflating: Positive/00020.jpg
#   inflating: Positive/00021.jpg
#   inflating: Positive/00022.jpg
#   inflating: Positive/00023.jpg
#   inflating: Positive/00024.jpg
#   inflating: Positive/00025.jpg
#   inflating: Positive/00026.jpg
#   inflating: Positive/00027.jpg
#   inflating: Positive/00028.jpg
#   inflating: Positive/00029.jpg
#   inflating: Positive/00030.jpg
#   inflating: Positive/00031.jpg
#   inflating: Positive/00032.jpg
#   inflating: Positive/00033.jpg
#   inflating: Positive/00034.jpg
#   inflating: Positive/00035.jpg
#   inflating: Positive/00036.jpg
#   inflating: Positive/00037.jpg
#   inflating: Positive/00038.jpg
#   inflating: Positive/00039.jpg
#   inflating: Positive/00040.jpg
#   inflating: Positive/00041.jpg
#   inflating: Positive/00042.jpg
#   inflating: Positive/00043.jpg
#   inflating: Positive/00044.jpg
#   inflating: Positive/00045.jpg
#   inflating: Positive/00046.jpg
#   inflating: Positive/00047.jpg
#   inflating: Positive/00048.jpg
#   inflating: Positive/00049.jpg
#   inflating: Positive/00050.jpg
#   inflating: Positive/00051.jpg
#   inflating: Positive/00052.jpg
#   inflating: Positive/00053.jpg
#   inflating: Positive/00054.jpg
#   inflating: Positive/00055.jpg
#   inflating: Positive/00056.jpg
#   inflating: Positive/00057.jpg
#   inflating: Positive/00058.jpg
#   inflating: Positive/00059.jpg
#   inflating: Positive/00060.jpg
#   inflating: Positive/00061.jpg
#   inflating: Positive/00062.jpg
#   inflating: Positive/00063.jpg
#   inflating: Positive/00064.jpg
#   inflating: Positive/00065.jpg
#   inflating: Positive/00066.jpg
#   inflating: Positive/00067.jpg
#   inflating: Positive/00068.jpg
#   inflating: Positive/00069.jpg
#   inflating: Positive/00070.jpg
#   inflating: Positive/00071.jpg
#   inflating: Positive/00072.jpg
#   inflating: Positive/00073.jpg
#   inflating: Positive/00074.jpg
#   inflating: Positive/00075.jpg
#   inflating: Positive/00076.jpg
#   inflating: Positive/00077.jpg
#   inflating: Positive/00078.jpg
#   inflating: Positive/00079.jpg
#   inflating: Positive/00080.jpg
#   inflating: Positive/00081.jpg
#   inflating: Positive/00082.jpg
#   inflating: Positive/00083.jpg
#   inflating: Positive/00084.jpg
#   inflating: Positive/00085.jpg
#   inflating: Positive/00086.jpg
#   inflating: Positive/00087.jpg
#   inflating: Positive/00088.jpg
#   inflating: Positive/00089.jpg
#   inflating: Positive/00090.jpg
#   inflating: Positive/00091.jpg
#   inflating: Positive/00092.jpg
#   inflating: Positive/00093.jpg
#   inflating: Positive/00094.jpg
#   inflating: Positive/00095.jpg
#   inflating: Positive/00096.jpg
#   inflating: Positive/00097.jpg
#   inflating: Positive/00098.jpg
#   inflating: Positive/00099.jpg
#   inflating: Positive/00100.jpg
#   inflating: Positive/00101.jpg
#   inflating: Positive/00102.jpg
#   inflating: Positive/00103.jpg
#   inflating: Positive/00104.jpg
#   inflating: Positive/00105.jpg
#   inflating: Positive/00106.jpg
#   inflating: Positive/00107.jpg
#   inflating: Positive/00108.jpg
#   inflating: Positive/00109.jpg
#   inflating: Positive/00110.jpg
#   inflating: Positive/00111.jpg
#   inflating: Positive/00112.jpg
#   inflating: Positive/00113.jpg
#   inflating: Positive/00114.jpg
#   inflating: Positive/00115.jpg
#   inflating: Positive/00116.jpg
#   inflating: Positive/00117.jpg
#   inflating: Positive/00118.jpg
#   inflating: Positive/00119.jpg
#   inflating: Positive/00120.jpg
#   inflating: Positive/00121.jpg
#   inflating: Positive/00122.jpg
#   inflating: Positive/00123.jpg
#   inflating: Positive/00124.jpg
#   inflating: Positive/00125.jpg
#   inflating: Positive/00126.jpg
#   inflating: Positive/00127.jpg
#   inflating: Positive/00128.jpg
#   inflating: Positive/00129.jpg
#   inflating: Positive/00130.jpg
#   inflating: Positive/00131.jpg
#   inflating: Positive/00132.jpg
#   inflating: Positive/00133.jpg
#   inflating: Positive/00134.jpg
#   inflating: Positive/00135.jpg
#   inflating: Positive/00136.jpg
#   inflating: Positive/00137.jpg
#   inflating: Positive/00138.jpg
#   inflating: Positive/00139.jpg
#   inflating: Positive/00140.jpg
#   inflating: Positive/00141.jpg
#   inflating: Positive/00142.jpg
#   inflating: Positive/00143.jpg
#   inflating: Positive/00144.jpg
#   inflating: Positive/00145.jpg
#   inflating: Positive/00146.jpg
#   inflating: Positive/00147.jpg
#   inflating: Positive/00148.jpg
#   inflating: Positive/00149.jpg
#   inflating: Positive/00150.jpg
#   inflating: Positive/00151.jpg
#   inflating: Positive/00152.jpg
#   inflating: Positive/00153.jpg
#   inflating: Positive/00154.jpg
#   inflating: Positive/00155.jpg
#   inflating: Positive/00156.jpg
#   inflating: Positive/00157.jpg
#   inflating: Positive/00158.jpg
#   inflating: Positive/00159.jpg
#   inflating: Positive/00160.jpg
#   inflating: Positive/00161.jpg
#   inflating: Positive/00162.jpg
#   inflating: Positive/00163.jpg
#   inflating: Positive/00164.jpg
#   inflating: Positive/00165.jpg
#   inflating: Positive/00166.jpg
#   inflating: Positive/00167.jpg
#   inflating: Positive/00168.jpg
#   inflating: Positive/00169.jpg
#   inflating: Positive/00170.jpg
#   inflating: Positive/00171.jpg
#   inflating: Positive/00172.jpg
#   inflating: Positive/00173.jpg
#   inflating: Positive/00174.jpg
#   inflating: Positive/00175.jpg
#   inflating: Positive/00176.jpg
#   inflating: Positive/00177.jpg
#   inflating: Positive/00178.jpg
#   inflating: Positive/00179.jpg
#   inflating: Positive/00180.jpg
#   inflating: Positive/00181.jpg
#   inflating: Positive/00182.jpg
#   inflating: Positive/00183.jpg
#   inflating: Positive/00184.jpg
#   inflating: Positive/00185.jpg
#   inflating: Positive/00186.jpg
#   inflating: Positive/00187.jpg
#   inflating: Positive/00188.jpg
#   inflating: Positive/00189.jpg
#   inflating: Positive/00190.jpg
#   inflating: Positive/00191.jpg
#   inflating: Positive/00192.jpg
#   inflating: Positive/00193.jpg
#   inflating: Positive/00194.jpg
#   inflating: Positive/00195.jpg
#   inflating: Positive/00196.jpg
#   inflating: Positive/00197.jpg
#   inflating: Positive/00198.jpg
#   inflating: Positive/00199.jpg
#   inflating: Positive/00200.jpg
#   inflating: Positive/00201.jpg
#   inflating: Positive/00202.jpg
#   inflating: Positive/00203.jpg
#   inflating: Positive/00204.jpg

# %%
# mounting google drive to colab to get the training data
#from google.colab import drive
#drive.mount('/content/drive')

# %% [markdown]
# !pip install torch
# !pip install torchvision
# !pip install torch

# %%
# !pip install https://files.pythonhosted.org/packages/8c/52/33d739bcc547f22c522def535a8da7e6e5a0f6b98594717f519b5cb1a4e1/torchvision-0.1.8-py2.py3-none-any.whl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchvision==0.1.8
#   Downloading torchvision-0.1.8-py2.py3-none-any.whl (37 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from torchvision==0.1.8) (1.12.1+cu113)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from torchvision==0.1.8) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from torchvision==0.1.8) (1.15.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision==0.1.8) (1.21.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->torchvision==0.1.8) (4.1.1)
# Installing collected packages: torchvision
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.13.1+cu113
#     Uninstalling torchvision-0.13.1+cu113:
#       Successfully uninstalled torchvision-0.13.1+cu113
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastai 2.7.9 requires torchvision>=0.8.2, but you have torchvision 0.1.8 which is incompatible.
# Successfully installed torchvision-0.1.8

# %% [markdown]
# ## Convolutional Neural Network is a type of neural network which uses a special operation called convolution.
#
# And it works best when we have image data.
#
# A typical pipeline of CNN looks like this.
#
# Input -> Convolutional layer -> Pooling layer -> Add non-linearity ( adding regularization and
#                                                                     activation functions)
#
# -> Fully connected layers -> Ouput
#
# There is a lot of preprocessing methods that can be used in between this pipeline.
#
# Convolution is a multiplication operation between an input and a filter. It's not a simple multiplication
# process, rather, it is computed by multiplying the input with the filter over a delayed period of time
#
#
# Input * filter -> Answer
#
# In CNN,
#
# filter
#
#
# filter = [[1,1,1],
#           [0,0,0],
#           [1,1,1]]
#
# filter2 = [[-1,-1,-1],[0,0,0],[-1,-1,-1]]
#
#
# Steps :
#
# step 1 : Load the image dataset.
# step 2 : preprocessing the image dataset
# step 3 : Then we define the resnet50 architecture and we add a custom layer for training our model
# step 4 : We train our model for 5 epochs.
# step 5 : We use the trained model to make inference of our test dataset
# step 6 : Visualize the results of our data

# %%
import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torch.utils.data import sampler
from torch.optim import lr_scheduler
from torchvision import datasets, models, transforms
import numpy as np
import os
cwd = os.getcwd()
from PIL import Image
import time
import copy
import random
import cv2
import re
import shutil
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %% [markdown]
# ## Load the Cracks Dataset and Visualize it
# * Link to the cracks data set:  https://data.mendeley.com/datasets/5y9wdsg2zt/2

# %%
crack_images = os.listdir('Positive/')
print("Number of Crack Images: ", len(crack_images))
# Out:
# Number of Crack Images:  204

# %%
no_crack_images = os.listdir('Negative/')
print("Number of No Crack Images: ", len(no_crack_images))
# Out:
# Number of No Crack Images:  207

# %%
## Visualize Random images with cracks
random_indices = np.random.randint(0, len(crack_images), size=4)
print("*****************Random Images with Cracks**************************")
random_images = np.array(crack_images)[random_indices.astype(int)]

f, axarr = plt.subplots(2,2)
axarr[0,0].imshow(mpimg.imread(os.path.join(cwd, 'Positive', random_images[0])))
axarr[0,1].imshow(mpimg.imread(os.path.join(cwd, 'Positive', random_images[1])))
axarr[1,0].imshow(mpimg.imread(os.path.join(cwd, 'Positive', random_images[2])))
axarr[1,1].imshow(mpimg.imread(os.path.join(cwd, 'Positive', random_images[3])))
# Out:
# *****************Random Images with Cracks**************************

# %%
## Visualize Random images with no cracks
random_indices = np.random.randint(0, len(no_crack_images), size=4)
print("*****************Random Images without Cracks**************************")
random_images = np.array(no_crack_images)[random_indices.astype(int)]

f, axarr = plt.subplots(2,2)
axarr[0,0].imshow(mpimg.imread(os.path.join(cwd, 'Negative', random_images[0])))
axarr[0,1].imshow(mpimg.imread(os.path.join(cwd, 'Negative', random_images[1])))
axarr[1,0].imshow(mpimg.imread(os.path.join(cwd, 'Negative', random_images[2])))
axarr[1,1].imshow(mpimg.imread(os.path.join(cwd, 'Negative', random_images[3])))
# Out:
# *****************Random Images without Cracks**************************

# %% [markdown]
# ## Create Train and Val Data sets

# %% [markdown]
# ### Create training folder

# %%
base_dir = cwd
files = os.listdir(base_dir)

def create_training_data(folder_name):
    train_dir = f"{base_dir}/train/{folder_name}"
    for f in files:
        search_object = re.search(folder_name, f)
        if search_object:
            shutil.move(f'{base_dir}/{folder_name}', train_dir)

# %%
create_training_data('Positive')
create_training_data('Negative')

# %% [markdown]
# ### Move images randomly from training to val folders

# %%
os.makedirs('val/Positive')
os.makedirs('val/Negative')

# %%
positive_train = base_dir + "/train/Positive/"
positive_val = base_dir + "/val/Positive/"
negative_train = base_dir + "/train/Negative/"
negative_val = base_dir + "/val/Negative/"

positive_files = os.listdir(positive_train)
negative_files = os.listdir(negative_train)

# %%
print(len(positive_files), len(negative_files))
# Out:
# 204 207

# %%
for f in positive_files:
    if random.random() > 0.80:
        shutil.move(f'{positive_train}/{f}', positive_val)

# %%
for f in negative_files:
    if random.random() > 0.80:
        shutil.move(f'{negative_train}/{f}', negative_val)

# %% [markdown]
# ## Pytorch data loader and transforms

# %% [markdown]
# ### Compute mean and std deviation for the dataset

# %%
mean_nums = [0.485, 0.456, 0.406]
std_nums = [0.229, 0.224, 0.225]

# there are three channels in an RGB IMAGE.
# 1. red
# 2. green
# 3. blue

# %%
import torchvision.transforms

# %%
## Define data augmentation and transforms
chosen_transforms = {'train': transforms.Compose([

        transforms.ToTensor(),
        transforms.Normalize(mean_nums, std_nums)
]), 'val': transforms.Compose([

        transforms.CenterCrop(227),
        transforms.ToTensor(),
        transforms.Normalize(mean_nums, std_nums)
]),
}

# %%
## Create the data loader
def load_dataset(format, batch_size):
    data_path = os.path.join(cwd, format)
    dataset = datasets.ImageFolder(
        root=data_path,
        transform= chosen_transforms[format]
    )
    data_loader = DataLoader(
        dataset,
        batch_size=batch_size,
        num_workers=4,
        shuffle=True
    )
    return data_loader, len(dataset), dataset.classes

# %%
## Set code to run on device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %%
train_loader, train_size, class_names = load_dataset('train', 8)
print("Train Data Set size is: ", train_size)
print("Class Names are: ", class_names)
inputs, classes = next(iter(train_loader))
print(inputs.shape, classes.shape)
# Out:
# Train Data Set size is:  323
# Class Names are:  ['Negative', 'Positive']
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# torch.Size([8, 3, 227, 227]) torch.Size([8])

# %% [markdown]
# ### Visualize the Augmented Data Set

# %%
# Visualize some images
def imshow(inp, title=None):
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([mean_nums])
    std = np.array([std_nums])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # Pause a bit so that plots are updated

# %%
# Grab some of the training data to visualize
inputs, classes = next(iter(train_loader))
# class_names = chosen_datasets['train'].classes
# Now we construct a grid from batch
out = torchvision.utils.make_grid(inputs)

idx_to_class = {0:'Negative', 1:'Positive'}
plt.figure(figsize=(20,10))
imshow(out, title=[x.data.numpy() for x in classes])

# %% [markdown]
# ## Set up Pretrained Model

# %%
## Load pretrained model
# residual networks. These are a special type of neural networks in contrast to fully connected networks.
# this solves the problem of vanishing gradients.
resnet50 = models.resnet50(pretrained=True)

# Freeze model parameters
for param in resnet50.parameters():
    param.requires_grad = False

## Change the final layer of the resnet model
# Change the final layer of ResNet50 Model for Transfer Learning
fc_inputs = resnet50.fc.in_features
 
resnet50.fc = nn.Sequential(
    nn.Linear(fc_inputs, 128),
    nn.ReLU(),
    nn.Dropout(0.4),
    nn.Linear(128, 2)
)

# Linear layer is an alias for fully connected layer. 
# Convert model to be used on GPU
resnet50 = resnet50.to(device)

from torchsummary import summary
print(summary(resnet50, (3, 227, 227)))
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/hub/checkpoints/resnet50-19c8e357.pth
#   0%|          | 0.00/97.8M [00:00<?, ?B/s]
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 114, 114]           9,408
#        BatchNorm2d-2         [-1, 64, 114, 114]             128
#               ReLU-3         [-1, 64, 114, 114]               0
#          MaxPool2d-4           [-1, 64, 57, 57]               0
#             Conv2d-5           [-1, 64, 57, 57]           4,096
#        BatchNorm2d-6           [-1, 64, 57, 57]             128
#               ReLU-7           [-1, 64, 57, 57]               0
#             Conv2d-8           [-1, 64, 57, 57]          36,864
#        BatchNorm2d-9           [-1, 64, 57, 57]             128
#              ReLU-10           [-1, 64, 57, 57]               0
#            Conv2d-11          [-1, 256, 57, 57]          16,384
#       BatchNorm2d-12          [-1, 256, 57, 57]             512
#            Conv2d-13          [-1, 256, 57, 57]          16,384
#       BatchNorm2d-14          [-1, 256, 57, 57]             512
#              ReLU-15          [-1, 256, 57, 57]               0
#        Bottleneck-16          [-1, 256, 57, 57]               0
#            Conv2d-17           [-1, 64, 57, 57]          16,384
#       BatchNorm2d-18           [-1, 64, 57, 57]             128
#              ReLU-19           [-1, 64, 57, 57]               0
#            Conv2d-20           [-1, 64, 57, 57]          36,864
#       BatchNorm2d-21           [-1, 64, 57, 57]             128
#              ReLU-22           [-1, 64, 57, 57]               0
#            Conv2d-23          [-1, 256, 57, 57]          16,384
#       BatchNorm2d-24          [-1, 256, 57, 57]             512
#              ReLU-25          [-1, 256, 57, 57]               0
#        Bottleneck-26          [-1, 256, 57, 57]               0
#            Conv2d-27           [-1, 64, 57, 57]          16,384
#       BatchNorm2d-28           [-1, 64, 57, 57]             128
#              ReLU-29           [-1, 64, 57, 57]               0
#            Conv2d-30           [-1, 64, 57, 57]          36,864
#       BatchNorm2d-31           [-1, 64, 57, 57]             128
#              ReLU-32           [-1, 64, 57, 57]               0
#            Conv2d-33          [-1, 256, 57, 57]          16,384
#       BatchNorm2d-34          [-1, 256, 57, 57]             512
#              ReLU-35          [-1, 256, 57, 57]               0
#        Bottleneck-36          [-1, 256, 57, 57]               0
#            Conv2d-37          [-1, 128, 57, 57]          32,768
#       BatchNorm2d-38          [-1, 128, 57, 57]             256
#              ReLU-39          [-1, 128, 57, 57]               0
#            Conv2d-40          [-1, 128, 29, 29]         147,456
#       BatchNorm2d-41          [-1, 128, 29, 29]             256
#              ReLU-42          [-1, 128, 29, 29]               0
#            Conv2d-43          [-1, 512, 29, 29]          65,536
#       BatchNorm2d-44          [-1, 512, 29, 29]           1,024
#            Conv2d-45          [-1, 512, 29, 29]         131,072
#       BatchNorm2d-46          [-1, 512, 29, 29]           1,024
#              ReLU-47          [-1, 512, 29, 29]               0
#        Bottleneck-48          [-1, 512, 29, 29]               0
#            Conv2d-49          [-1, 128, 29, 29]          65,536
#       BatchNorm2d-50          [-1, 128, 29, 29]             256
#              ReLU-51          [-1, 128, 29, 29]               0
#            Conv2d-52          [-1, 128, 29, 29]         147,456
#       BatchNorm2d-53          [-1, 128, 29, 29]             256
#              ReLU-54          [-1, 128, 29, 29]               0
#            Conv2d-55          [-1, 512, 29, 29]          65,536
#       BatchNorm2d-56          [-1, 512, 29, 29]           1,024
#              ReLU-57          [-1, 512, 29, 29]               0
#        Bottleneck-58          [-1, 512, 29, 29]               0
#            Conv2d-59          [-1, 128, 29, 29]          65,536
#       BatchNorm2d-60          [-1, 128, 29, 29]             256
#              ReLU-61          [-1, 128, 29, 29]               0
#            Conv2d-62          [-1, 128, 29, 29]         147,456
#       BatchNorm2d-63          [-1, 128, 29, 29]             256
#              ReLU-64          [-1, 128, 29, 29]               0
#            Conv2d-65          [-1, 512, 29, 29]          65,536
#       BatchNorm2d-66          [-1, 512, 29, 29]           1,024
#              ReLU-67          [-1, 512, 29, 29]               0
#        Bottleneck-68          [-1, 512, 29, 29]               0
#            Conv2d-69          [-1, 128, 29, 29]          65,536
#       BatchNorm2d-70          [-1, 128, 29, 29]             256
#              ReLU-71          [-1, 128, 29, 29]               0
#            Conv2d-72          [-1, 128, 29, 29]         147,456
#       BatchNorm2d-73          [-1, 128, 29, 29]             256
#              ReLU-74          [-1, 128, 29, 29]               0
#            Conv2d-75          [-1, 512, 29, 29]          65,536
#       BatchNorm2d-76          [-1, 512, 29, 29]           1,024
#              ReLU-77          [-1, 512, 29, 29]               0
#        Bottleneck-78          [-1, 512, 29, 29]               0
#            Conv2d-79          [-1, 256, 29, 29]         131,072
#       BatchNorm2d-80          [-1, 256, 29, 29]             512
#              ReLU-81          [-1, 256, 29, 29]               0
#            Conv2d-82          [-1, 256, 15, 15]         589,824
#       BatchNorm2d-83          [-1, 256, 15, 15]             512
#              ReLU-84          [-1, 256, 15, 15]               0
#            Conv2d-85         [-1, 1024, 15, 15]         262,144
#       BatchNorm2d-86         [-1, 1024, 15, 15]           2,048
#            Conv2d-87         [-1, 1024, 15, 15]         524,288
#       BatchNorm2d-88         [-1, 1024, 15, 15]           2,048
#              ReLU-89         [-1, 1024, 15, 15]               0
#        Bottleneck-90         [-1, 1024, 15, 15]               0
#            Conv2d-91          [-1, 256, 15, 15]         262,144
#       BatchNorm2d-92          [-1, 256, 15, 15]             512
#              ReLU-93          [-1, 256, 15, 15]               0
#            Conv2d-94          [-1, 256, 15, 15]         589,824
#       BatchNorm2d-95          [-1, 256, 15, 15]             512
#              ReLU-96          [-1, 256, 15, 15]               0
#            Conv2d-97         [-1, 1024, 15, 15]         262,144
#       BatchNorm2d-98         [-1, 1024, 15, 15]           2,048
#              ReLU-99         [-1, 1024, 15, 15]               0
#       Bottleneck-100         [-1, 1024, 15, 15]               0
#           Conv2d-101          [-1, 256, 15, 15]         262,144
#      BatchNorm2d-102          [-1, 256, 15, 15]             512
#             ReLU-103          [-1, 256, 15, 15]               0
#           Conv2d-104          [-1, 256, 15, 15]         589,824
#      BatchNorm2d-105          [-1, 256, 15, 15]             512
#             ReLU-106          [-1, 256, 15, 15]               0
#           Conv2d-107         [-1, 1024, 15, 15]         262,144
#      BatchNorm2d-108         [-1, 1024, 15, 15]           2,048
#             ReLU-109         [-1, 1024, 15, 15]               0
#       Bottleneck-110         [-1, 1024, 15, 15]               0
#           Conv2d-111          [-1, 256, 15, 15]         262,144
#      BatchNorm2d-112          [-1, 256, 15, 15]             512
#             ReLU-113          [-1, 256, 15, 15]               0
#           Conv2d-114          [-1, 256, 15, 15]         589,824
#      BatchNorm2d-115          [-1, 256, 15, 15]             512
#             ReLU-116          [-1, 256, 15, 15]               0
#           Conv2d-117         [-1, 1024, 15, 15]         262,144
#      BatchNorm2d-118         [-1, 1024, 15, 15]           2,048
#             ReLU-119         [-1, 1024, 15, 15]               0
#       Bottleneck-120         [-1, 1024, 15, 15]               0
#           Conv2d-121          [-1, 256, 15, 15]         262,144
#      BatchNorm2d-122          [-1, 256, 15, 15]             512
#             ReLU-123          [-1, 256, 15, 15]               0
#           Conv2d-124          [-1, 256, 15, 15]         589,824
#      BatchNorm2d-125          [-1, 256, 15, 15]             512
#             ReLU-126          [-1, 256, 15, 15]               0
#           Conv2d-127         [-1, 1024, 15, 15]         262,144
#      BatchNorm2d-128         [-1, 1024, 15, 15]           2,048
#             ReLU-129         [-1, 1024, 15, 15]               0
#       Bottleneck-130         [-1, 1024, 15, 15]               0
#           Conv2d-131          [-1, 256, 15, 15]         262,144
#      BatchNorm2d-132          [-1, 256, 15, 15]             512
#             ReLU-133          [-1, 256, 15, 15]               0
#           Conv2d-134          [-1, 256, 15, 15]         589,824
#      BatchNorm2d-135          [-1, 256, 15, 15]             512
#             ReLU-136          [-1, 256, 15, 15]               0
#           Conv2d-137         [-1, 1024, 15, 15]         262,144
#      BatchNorm2d-138         [-1, 1024, 15, 15]           2,048
#             ReLU-139         [-1, 1024, 15, 15]               0
#       Bottleneck-140         [-1, 1024, 15, 15]               0
#           Conv2d-141          [-1, 512, 15, 15]         524,288
#      BatchNorm2d-142          [-1, 512, 15, 15]           1,024
#             ReLU-143          [-1, 512, 15, 15]               0
#           Conv2d-144            [-1, 512, 8, 8]       2,359,296
#      BatchNorm2d-145            [-1, 512, 8, 8]           1,024
#             ReLU-146            [-1, 512, 8, 8]               0
#           Conv2d-147           [-1, 2048, 8, 8]       1,048,576
#      BatchNorm2d-148           [-1, 2048, 8, 8]           4,096
#           Conv2d-149           [-1, 2048, 8, 8]       2,097,152
#      BatchNorm2d-150           [-1, 2048, 8, 8]           4,096
#             ReLU-151           [-1, 2048, 8, 8]               0
#       Bottleneck-152           [-1, 2048, 8, 8]               0
#           Conv2d-153            [-1, 512, 8, 8]       1,048,576
#      BatchNorm2d-154            [-1, 512, 8, 8]           1,024
#             ReLU-155            [-1, 512, 8, 8]               0
#           Conv2d-156            [-1, 512, 8, 8]       2,359,296
#      BatchNorm2d-157            [-1, 512, 8, 8]           1,024
#             ReLU-158            [-1, 512, 8, 8]               0
#           Conv2d-159           [-1, 2048, 8, 8]       1,048,576
#      BatchNorm2d-160           [-1, 2048, 8, 8]           4,096
#             ReLU-161           [-1, 2048, 8, 8]               0
#       Bottleneck-162           [-1, 2048, 8, 8]               0
#           Conv2d-163            [-1, 512, 8, 8]       1,048,576
#      BatchNorm2d-164            [-1, 512, 8, 8]           1,024
#             ReLU-165            [-1, 512, 8, 8]               0
#           Conv2d-166            [-1, 512, 8, 8]       2,359,296
#      BatchNorm2d-167            [-1, 512, 8, 8]           1,024
#             ReLU-168            [-1, 512, 8, 8]               0
#           Conv2d-169           [-1, 2048, 8, 8]       1,048,576
#      BatchNorm2d-170           [-1, 2048, 8, 8]           4,096
#             ReLU-171           [-1, 2048, 8, 8]               0
#       Bottleneck-172           [-1, 2048, 8, 8]               0
#        AvgPool2d-173           [-1, 2048, 1, 1]               0
#           Linear-174                  [-1, 128]         262,272
#             ReLU-175                  [-1, 128]               0
#          Dropout-176                  [-1, 128]               0
#           Linear-177                    [-1, 2]             258
# ================================================================
# Total params: 23,770,562
# Trainable params: 262,530
# Non-trainable params: 23,508,032
# ----------------------------------------------------------------
# Input size (MB): 0.59
# Forward/backward pass size (MB): 309.46
# Params size (MB): 90.68
# Estimated Total Size (MB): 400.72
# ----------------------------------------------------------------
# None

# %%
# Define Optimizer and Loss Function
# learning rate decay. As we train the model, we can decide to change the learning rate dynamically.
# the schedular helps us in doing that.
#@ IN THE FIRST epoch, the learning rate was 0.1, then the learning rate in epoch 4 would be 0.01. 
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(resnet50.parameters())
# optimizer = optim.SGD(resnet50.fc.parameters(), lr=0.001, momentum=0.9)
# Decay LR by a factor of 0.1 every 3 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=3, gamma=0.1)

# %%
dataloaders = {}
dataset_sizes = {}
batch_size = 256
dataloaders['train'], dataset_sizes['train'], class_names = load_dataset('train', batch_size)
dataloaders['val'], dataset_sizes['val'], _ = load_dataset('val', batch_size)
idx_to_class = {0:'Negative', 1:'Positive'}

# %% [markdown]
# ## Start training

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=10):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                scheduler.step()
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            current_loss = 0.0
            current_corrects = 0

            # Here's where the training happens
            print('Iterating through data...')
# training starts...
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # We need to zero the gradients, don't forget it
# Re-setting all of model parameters
                optimizer.zero_grad()
                # Time to carry out the forward training poss
                # We only need to log the loss stats if we are in training phase
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    # this computes the class that the model belongs to...
                    _, preds = torch.max(outputs, 1)
                    # compute the loss here...
                    # we compute the difference between true label and the predicted output...
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward() # this is the back-propragation step. we 
                        # minimize our model loss and optimize model in this phase
                        optimizer.step()
                        # optimizer updates the model paramters...
                        

                # We want variables to hold the loss statistics
                # combine our model losses and compute the wrongly classified examples
                current_loss += loss.item() * inputs.size(0)
                current_corrects += torch.sum(preds == labels.data)
            # compute the loss and accuracy for each of our epoch
            epoch_loss = current_loss / dataset_sizes[phase]
            epoch_acc = current_corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            # Make a copy of the model if the accuracy on the validation set has improved
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_since = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_since // 60, time_since % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # Now we'll load in the best model weights and return it
    model.load_state_dict(best_model_wts)
    return model

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_handeled = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_handeled += 1
                ax = plt.subplot(num_images//2, 2, images_handeled)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                imshow(inputs.cpu().data[j])

                if images_handeled == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
base_model = train_model(resnet50, criterion, optimizer, exp_lr_scheduler, num_epochs=6)
visualize_model(base_model)
plt.show()
# an epoch is the total time during which one training step completes. In other words, it is the total
# time that our model takes to process the input data once...
# Out:
# Epoch 0/5
# ----------
# Iterating through data...
# /usr/local/lib/python3.7/dist-packages/torch/optim/lr_scheduler.py:136: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# train Loss: 0.6491 Acc: 0.5882
# Iterating through data...
# val Loss: 0.6748 Acc: 0.4773
#
# Epoch 1/5
# ----------
# Iterating through data...
# train Loss: 0.5283 Acc: 0.6718
# Iterating through data...
# val Loss: 0.4589 Acc: 0.8864
#
# Epoch 2/5
# ----------
# Iterating through data...

# %% [markdown]
# ## Inference

# %%
def predict(model, test_image, print_class = False):
     # it uses the model to predict on test_image...
    transform = chosen_transforms['val']
     
    test_image_tensor = transform(test_image)
    if torch.cuda.is_available(): # checks if we have a gpu available
        test_image_tensor = test_image_tensor.view(1, 3, 227, 227).cuda()
    else:
        test_image_tensor = test_image_tensor.view(1, 3, 227, 227)
    
    with torch.no_grad():
        model.eval()
        # Model outputs log probabilities
        # this computes the output of the model
        out = model(test_image_tensor)
        # this computes the probability of each classes.
        ps = torch.exp(out)
        # we choose the top class. That is, the class with highest probability
        topk, topclass = ps.topk(1, dim=1)
        class_name = idx_to_class[topclass.cpu().numpy()[0][0]]
        if print_class:
            print("Output class :  ", class_name)
    return class_name

# %%
def predict_on_crops(input_image, height=227, width=227, save_crops = False):
    im = cv2.imread(input_image)
    imgheight, imgwidth, channels = im.shape
    k=0
    output_image = np.zeros_like(im)
    for i in range(0,imgheight,height):
        for j in range(0,imgwidth,width):
            a = im[i:i+height, j:j+width]
            ## discard image cropss that are not full size
            predicted_class = predict(base_model,Image.fromarray(a))
            ## save image
            file, ext = os.path.splitext(input_image)
            image_name = file.split('/')[-1]
            folder_name = 'out_' + image_name
            ## Put predicted class on the image
            if predicted_class == 'Positive':
                color = (0,0, 255)
            else:
                color = (0, 255, 0)
            cv2.putText(a, predicted_class, (50,50), cv2.FONT_HERSHEY_SIMPLEX , 0.7, color, 1, cv2.LINE_AA) 
            b = np.zeros_like(a, dtype=np.uint8)
            b[:] = color
            add_img = cv2.addWeighted(a, 0.9, b, 0.1, 0)
            ## Save crops
            if save_crops:
                if not os.path.exists(os.path.join('real_images', folder_name)):
                    os.makedirs(os.path.join('real_images', folder_name))
                filename = os.path.join('real_images', folder_name,'img_{}.png'.format(k))
                cv2.imwrite(filename, add_img)
            output_image[i:i+height, j:j+width,:] = add_img
            k+=1
    ## Save output image
    cv2.imwrite(os.path.join('real_images','predictions', folder_name+ '.jpg'), output_image)
    return output_image

# %%
plt.figure(figsize=(10,10))
output_image = predict_on_crops('/content/val/Positive/00004.jpg', 128, 128)
plt.imshow(cv2.cvtColor(output_image, cv2.COLOR_BGR2RGB))
