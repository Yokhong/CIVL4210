# %% [markdown]
# # Assignment 2 (or 1)

# %% [markdown]
# In this notebook, we will use the human keypoint data, read the data from the .txt document, and draw the human pose in 3-D space.

# %% [markdown]
# # 1.Background information
#
# 1).Human Pose Estimation - keypoint
#
# In order to represent the human pose, the human body is usually divided into different keypoints, such as the COCO dataset with 17 keypoint types.The body parts 17 key points include: 0: nose, 1: left eye, 2: right eye, 3: left ear, 4: right ear, 5: left shoulder, 6: right shoulder, 7: left elbow, 8: right elbow, 9: left wrist, 10: right wrist, 11: left crotch, 12: right crotch, 13: left knee, 14: right knee, 15: left ankle, 16: right ankle.
# ![image.png](attachment:image.png)
#
# 2).Matplotlib
#
# Matplotlib is a drawing library for the Python language and its numerical computation library NumPy. It can draw 2D and 3D pictures.

# %% [markdown]
# ## Plot a curve

# %% [markdown]
# See the difference when you change A and B.😊

# %%
import matplotlib.pyplot as plt
# Matplotlib.pyplot is a collection of functions that provides a MATLAB-like plotting framework in Python.
# In Python, the 'import' statement is used to bring in external modules or libraries into your current Python script.
# In this line: To make it easier for us to use the library later, we shortened its name to "as."

import numpy as np
# Same as the first lane.
# Numpy is a powerful library for working with numerical data in Python, providing functionality for performing mathematical operations on arrays and matrices.

a=np.linspace(0,10,100)
# a=np.linspace(0,20,100) # example ## # Now try to change it by yourself!😊
# a=np.linspace(0,10,200) # example ## # Now try to change it by yourself!😊
# numpy.linspace() can return an array of evenly spaced numbers within a specified range.
# The syntax for the function is as follows:
# numpy.linspace(start, stop, num=50, endpoint=True, retstep=False, dtype=None)
# The function takes in three required arguments - start(=0), stop(=10), and num(=100).

b=np.exp(-a)
# b=np.exp(a) # example ## # Now try to change it by yourself!😊
# numpy.exp() returns the exponential value of an input array.
# The syntax for the function is as follows:
# numpy.exp(x, /, out=None, *, where=True, casting='same_kind', order='K', dtype=None, subok=True[, signature, extobj])
# The function takes in one required argument - x, which is an array-like object containing the input values.
# The function returns an array of the same shape as x, with each element in the output array equal to the exponential value of the corresponding element in the input array.

plt.plot(a,b)
# Draw the plot: a as the x-axis, b as the y-axis.
plt.show
# Show or print the plot.
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# It's your turn now.😊

# %%
import matplotlib.pyplot as plt
import numpy as np

A=np.linspace(0,10,100)
# a=np.linspace(0,20,100) # example ## # Now try to change it by yourself!😊
# a=np.linspace(0,10,200) # example ## # Now try to change it by yourself!😊

B=np.exp(A)
# b=np.exp(-a) # example ## # Now try to change it by yourself!😊

plt.plot(A,B)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Draw a surface

# %% [markdown]
# Try to change 'X,Y arange', 'R', 'Z', 'surf', 'view_init'😊

# %%
import matplotlib.pyplot as plt
# matplotlib.pyplot provide a convenient interface for creating various types of plots and visualizations.
# Matplotlib is a popular data visualization library in Python.
# Pyplot provides a simple and intuitive way to create and customize plots.

from mpl_toolkits.mplot3d import Axes3D
# The mpl_toolkits.mplot3d module provides the necessary classes and functions for creating 3D plots.
# The Axes3D class provides a 3D plotting space where data can be plotted in three dimensions.

import numpy as np
# The numpy provides a powerful array and matrix manipulation functionality.
# It is often used in conjunction with the Locator and Formatter classes to customize the appearance of tick marks and labels on a plot.
# The MultipleLocator class takes a single argument, which is the interval at which ticks should be placed on the axis.

from matplotlib.pyplot import MultipleLocator
# MultipleLocator provides a way to set the location of ticks on an axis at regular intervals.
# Please jump tp 'Build 3D image with Matplotlib. pyplot module'.

fig=plt.figure()
# Create a new figure object.
# The matplotlib.pyplot.figure() creates a new figure object with a specified size and other optional parameters.
# It can be used to create a new blank figure or to replace an existing figure.

ax=fig.add_axes(Axes3D(fig))
# ax=fig.gca(projection='3d')
# Add a new set of 3D axes to the figure.
# The Axes3D(fig) argument specifies that the new axes should be of the 3D variety.


X=np.arange(-5,5,0.25)
Y=np.arange(-5,5,0.25)
# The numpy.arange() takes three arguments: start, stop, and step.
# It returns an array of values that starts at the start value, ends at the stop value (but does not include it) and increments by the step value.

X,Y=np.meshgrid(X,Y)
# The numpy.meshgrid() returns coordinate matrices from two or more coordinate vectors.
# The numpy.meshgrid() takes two or more 1-D arrays and returns two or more N-dimensional coordinate arrays for the input arrays.
# These arrays can be used to create a grid of points for plotting 3D surfaces or for performing operations on the grid.

R=np.sqrt(X**2+Y**2)
# The numpy.sqrt() returns the square root of the input array element-wise.
# In Python, we use AAA**n to represent AAA^n(nth power of AAA).

Z=np.sin(R)
# The numpy.sin() returns the sine of the input array element-wise.

surf=ax.plot_surface(X,Y,Z,cmap='viridis')
# The plot_surface(X,Y,Z) creates a 3D surface plot from three-dimensional data represented by the X, Y, and Z arrays.
# The cmap argument specifies the colormap that is applied to the surface plot.

# ax.plot_wireframe(X,Y,Z,color='pink') # example
# The plot_wireframe() creates a 3D wireframe plot from three-dimensional data.

ax.set_title('Example') # example
# Set the title in the plot.

ax.view_init(35,35,0) # example
# sets the elevation, azimuth and rotation angles of the 3D plot view.

plt.show()

# %% [markdown]
# It's your turn now!😊

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
from matplotlib.pyplot import MultipleLocator
fig=plt.figure()

ax=fig.add_axes(Axes3D(fig))
X2=np.arange(-10,10,0.25) # Now try to change it by yourself!😊
Y2=np.arange(-10,10,0.25) # Now try to change it by yourself!😊
X2,Y2=np.meshgrid(X2,Y2)
R2=R2=Y2*np.sin(X2)-X2*np.cos(Y2) # Now try to change it by yourself!😊
Z2=R2 # Now try to change it by yourself!😊
surf=ax.plot_surface(X2,Y2,Z2,cmap='viridis') # Now try to change it by yourself!😊
ax.plot_wireframe(X2,Y2,Z2,color='white')  # Now try to change it by yourself!😊
ax.set_title('wireframe') # Now try to change it by yourself!😊
ax.view_init(40,60,0)  # Now try to change it by yourself!😊

plt.show()

# Example:
# R2=np.sqrt(X2**2+Y2**2) Z2=np.sin(R2)/R2
# R2=np.sin(X2)+np.cos(Y2) Z2=np.sqrt(R2)
# R2=Y2*np.sin(X2)-X2*np.cos(Y2) Z2=R2

# %% [markdown]
# # 2. Drawing of human posture.

# %% [markdown]
# # Fire up matplotlib create

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import MultipleLocator
# initialization

# %% [markdown]
# # Establish connections between keypoints

# %% [markdown]
# Define a principal function that draws the connections between the human skeleton.
# Link establishes the connection between all points. Here, 0-18 represents a feature point in a joint,
# for example, 0 represents the top of the head, 2,3 represents the left and right eyes, etc.
# For example, [0,2] represents the connection between feature point 0 and feature point 2.
# In the loop, index1 and index2 represent each point of link. Use the POLT function to draw the connection between each
# two points through a loop.

# %%
def renderBones(): # define a function
   link = [[0,2],[0,3],[2,5],[3,6],[1,5],[1,6]
             ,[5,11],[11,15],[6,12],[12,16]
             ,[3,8],[8,14],[14,17],[2,7],[7,13],[13,18]
             ,[1,4],[4,9],[4,10]]
   for l in link:
       index1,index2 = l[0],l[1]
       ax.plot([xs[index1],xs[index2]], [ys[index1],ys[index2]], [zs[index1],zs[index2]], linewidth=1, label=r'$z=y=x$')

# %% [markdown]
# # Build 3D image with Matplotlib. pyplot module

# %%
x_major_locator = MultipleLocator(0.5) # The number will be changed later.😊
# The MultipleLocator class takes a single argument, which is the base value that the tick locations should be set at multiples of it.
# For example, if the base value is set to 2, the tick locations will be set at 2, 4, 6, ... on the axis.

fig = plt.figure()

ax = fig.add_subplot(111, projection='3d')
# The add_subplot(*args, **kwargs) creates a new subplot in a figure.
# The method takes variable-length arguments and keyword arguments that can be used to specify the number of rows, number of columns, and index of the subplot, as well as other optional parameters such as the projection type and axis labels.
# *args : int, (int, int, *index*), or .SubplotSpec, default: (1, 1, 1)
# The argument 111 is a shorthand notation for specifying the layout of subplots in a figure.
# The 111 argument is equivalent to specifying nrows=1, ncols=1, and index=1.
# This means that the figure contains a single subplot in a grid of 1 row by 1 column, and the subplot is located in the first (and only) position of the grid.

ax.xaxis.set_major_locator(x_major_locator)
ax.yaxis.set_major_locator(x_major_locator)
ax.zaxis.set_major_locator(x_major_locator)
# Here, xaxis represents the x-axis of the plot, and x_major_locator represents the Locator object that specifies the locations of the major ticks on the x-axis.
# The x_major_locator variable should be set to a matplotlib.ticker object that specifies the location of the major ticks on the x-axis.

# %% [markdown]
# MultipleLocator is customize the scale interval

# %%
x_major_locator = MultipleLocator(0.5)

# %% [markdown]
# Through the sensor to obtain the position of the body posture, and recorded in the 1.txt.

# %%
#Import human keypoint data. Because it's a 3D model, every point has x, y, and z coordinates.
# XS is the x-coordinate of the 17 key points from 0 to 17.

# %% [markdown]
# # Read the data

# %%
#Read data from a TXT file and store it in a list

# %%
import urllib.request
url='https://raw.githubusercontent.com/Yokhong/CIVL4210/main/H2_human_pose_in_3D_space/humanpose_data.txt'
urllib.request.urlretrieve(url, "/content/humanpose_data.txt")
file="humanpose_data.txt" # relative address (computing)
# file="/content/humanpose_data.txt" # absolute address (computing)

nl=[]
# This initializes an empty list called nl that will be used to store the numerical values extracted from the file.
with open (file) as f :
# This opens the file specified by file in a context manager, which automatically closes the file when the code block is finished.
    for line in f:
# This loops through each line in the file.
        nl.extend([float(i) for i in line.split()])
# This extracts the numerical values from the current line by splitting it into a list of strings using the split() method, and then converting each string to a float using the float() function.
# The resulting list of floats is then added to the nl list using the extend() method.

xs=nl[0:19]
# nl[0:19] selects the elements of nl starting from index 0 (the first element) up to, but not including, index 19 (the 20th element).
print(xs)
ys=nl[19:38]
print(ys)
zs=nl[38:57]
print(zs)
# Out:
# [1.2, 1.2622, 1.31214, 1.12714, 1.08315, 1.35968, 1.13569, 1.33013, 1.05112, 1.21635, 1.15264, 1.45452, 1.09412, 1.35265, 1.0675, 1.25544, 1.01167, 0.951523, 1.31394]
# [-0.565064, -0.550035, -0.495435, -0.612834, -0.324778, -0.460297, -0.615028, -0.514095, -0.602575, -0.410043, -0.453141, -0.450693, -0.746307, -0.543584, -0.664165, -0.328582, -0.53586, -0.614461, -0.420351]
# [0.81514, 1.35549, 0.810555, 0.824702, 1.58366, 1.33596, 1.36724, 0.404219, 0.413127, 1.56018, 1.56505, 1.07123, 1.12532, -0.00409877, 0.0153292, 1.02795, 1.03707, -0.0496544, -0.0499604]

# %%
# Run the keypoint connection function we defined above.Set coordinate properties

# %% [markdown]
# # Draw 3-D human pose

# %%
fig = plt.figure()

ax = fig.add_subplot(111, projection='3d')
renderBones()
# We have already defined this function. So use it!😊

ax.scatter(xs,ys,zs)
# The scatter() create a 3D scatter plot using the specified x, y, and z coordinates.

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
# The set_xlabel method sets the label of the x-axis to the string specified in the argument.

ax.set_xlim(-1,1)
ax.set_ylim(-1,1)
ax.set_zlim(-1,1)
# The set_xlim method sets the limits of the x-axis to the values specified in the arguments.
# In this case, the lower limit of the x-axis is set to -1 and the upper limit is set to 1.
# By setting the label of the x-axis, we can provide information about the data being plotted along the x-axis.
ax.view_init(40,60,0)
ax.set_title('3-D human pose')
plt.show()

# %% [markdown]
# #Assignment requirement:
# 1. Change the raw data into the format that your code can read.
# 2. Define a function in which you can join the key points together.
# 3. Load the files you changed and print out XS, YS, and ZS.
# 4. Change the view to elevation angles of 40, azimuth angles of 60, and rotation angles of 0.
# 5. Plot the 3D human pose and save the picture on your computer.
# 6. Please use the last digit of your school number to select the corresponding data number.
# (For example, your student ID is <font color="red">20942549</font>, so you need to select the data numbered <font color="red">nine</font>.)
#
# In CANVAS, You can find the data in the course folder <font color="red">“W4 Assignment.”</font>
#
# What you need to submit in Canvas are <font color="red">an ipynb file </font>and <font color="red">a picture of the 3D human pose</font>.
#
# #Sample:
# ![圖片2.png](data:image/png;base64,...)![圖片1.jpg](data:image/jpeg;base64,...)
#
#
# #Appendix
# NUMBER	NAME
#
# 0	neck
#
# 1	L-eye
#
# 2	R-eye
#
# 3	L-ear
#
# 4	R-ear
#
# 5	L-shoulder
#
# 6	R-shoulder
#
# 7	L-elbow
#
# 8	R-elbow
#
# 9	L-wrist
#
# 10	R-wrist
#
# 11	L-hip
#
# 12	R-hip
#
# 13	L-knee
#
# 14	R-knee
#
# 15	L-ankle
#
# 16	R-ankle
# ![4fb7cd9c1e82a4a5480e7cd97f796b2.jpg](data:image/jpeg;base64,...)![圖片3.jpg](data:image/jpeg;base64,...)
